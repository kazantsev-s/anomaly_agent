# %% [markdown]
# # LangGraph visualization
#
# Визуалиация графов

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / 'src'))

# %%
# !pip install ipython
# Out:
# Requirement already satisfied: ipython in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (9.15.0)
# Requirement already satisfied: decorator>=5.1.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (3.0.52)
# Requirement already satisfied: psutil>=7 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from ipython) (5.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from jedi>=0.18.2->ipython) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from pexpect>4.6->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.8.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython) (3.0.2)
# Requirement already satisfied: pure-eval in /Users/ksa/CodeProjects/anomaly_agent/anomaly_agent/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from agent.ask_graph import ask_graph
from agent.analyze_graph import analyze_graph
from IPython.display import Image

print('Ask graph:')
display(Image(ask_graph.get_graph().draw_mermaid_png()))

print('Analyze graph:')
display(Image(analyze_graph.get_graph().draw_mermaid_png()))
# Out:
# Ask graph:
# Analyze graph:
